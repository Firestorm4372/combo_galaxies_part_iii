# %%
import numpy as np

import combo

# %matplotlib widget

# %% [markdown]
# # Generate

# %%
gen = combo.generate_seds.Generate('more_variation', 'with more variation in parameters, using suggestions from Sandro')

# %%
gen.fake_galaxies()
# Out:
# Read config: .data/1_more_variation/config.yml
# Drawing galaxies...
# dict_keys(['norm', 'zred', 'dust2', 'tage', 'tau', 'igm_factor', 'logzsol'])
# True
# model free parameters are ['zred', 'logzsol', 'dust2', 'tage', 'tau', 'igm_factor', 'gas_logu']
# free parameter gas_logu does not have a source distribution
# Galaxies drawn.
# Generating catalog...
# ['F070W', 'F090W', 'F115W', 'F150W', 'F162M', 'F182M', 'F200W', 'F210M', 'F250M', 'F277W', 'F277WA', 'F277WB', 'F300M', 'F335M', 'F335MA', 'F335MB', 'F356W', 'F356WA', 'F356WB', 'F410M', 'F410MA', 'F410MB', 'F444W', 'F444WA', 'F444WB', 'F435W', 'F606W', 'F775W', 'F814W', 'F850LP', 'F105W', 'F125W', 'F140W', 'F160W']
# Catalog generated.
# Writing image...
# Successfully wrote image to .data/1_more_variation/fake_catalog_raw.fits

# %%
gen.parse_catalog()

# %% [markdown]
# # Select

# %%
sel = combo.select_galaxies.Select('1_more_variation')

# %%
z_vals = np.arange(20, 140, dtype=int) / 10
z_vals = np.repeat(z_vals, 1)
# combinations = [2,3,4,5,10,15,20]
combinations = [2,3,4,5]

# %%
sel.create_and_save_galaxies(z_vals, combinations, 0.1, 'full_range', 'Full redshift range, but only 1 at each and combos of 2,3,4,5')
# Out:
# <Table length=2160>
#   id     zred  combo ...         E140W                  E160W
# int64  float64 int64 ...        float64                float64
# ------ ------- ----- ... ---------------------- ----------------------
# 100001     2.0     2 ...  6.303736859639562e-05   8.14136128466465e-05
#  22135     2.0     1 ...  2.982408809957418e-05 3.8168555985477355e-05
#  88465     2.0     1 ...  5.553587676976644e-05  7.191201353548043e-05
# 100002     2.0     3 ...   0.003536492254777914   0.004276212583820624
#  31623     2.0     1 ...    0.00350039044275626   0.004224111563515091
#   9408     2.0     1 ...  0.0004748128688668406  0.0006397153307783774
#   6715     2.0     1 ...   0.000169106345011794 0.00018341171328749544
# 100003     2.0     4 ...   0.001460379113218295   0.001594596048568408
#   4672     2.0     1 ...  0.0007688405012013294  0.0008679370915135185
#  70603     2.0     1 ...  0.0004891911959686082  0.0005485088608527801
# ...

# %% [markdown]
# # Run

# %%
run = combo.run_eazy.RunEAZY('1_more_variation', '0_full_range')

# %%
run.EAZY_run()
# Out:
# Read default param file: /Users/liambrown/repositories/combo_galaxies_part_iii/.venv/lib/python3.12/site-packages/eazy/data/zphot.param.default
# Read CATALOG_FILE: .data/1_more_variation/0_full_range/EAZY_input.csv
#    >>> NOBJ = 2160
# F070W E070W (362): jwst_nircam_f070w
# F090W E090W (363): jwst_nircam_f090w
# F115W E115W (364): jwst_nircam_f115w
# F150W E150W (365): jwst_nircam_f150w
# F162M E162M (369): jwst_nircam_f162m
# F182M E182M (370): jwst_nircam_f182m
# F200W E200W (366): jwst_nircam_f200w
# F210M E210M (371): jwst_nircam_f210m
# F250M E250M (379): jwst_nircam_f250m
# F277W E277W (375): jwst_nircam_f277w
# F300M E300M (380): jwst_nircam_f300m
# F335M E335M (381): jwst_nircam_f335m
# F356W E356W (376): jwst_nircam_f356w
# F410M E410M (383): jwst_nircam_f410m
# F444W E444W (377): jwst_nircam_f444w
# F435W E435W (233): hst/ACS_update_sep07/wfc_f435w_t81.dat
# F606W E606W (236): hst/ACS_update_sep07/wfc_f606w_t81.dat
# ...

# %%
fig = run.photoz.zphot_zspec(zmin=2, zmax=14)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Analyse

# %% [markdown]
# Maybe should do rms error, not mean of absolute

# %%
ana = combo.analyse_data.Analyse('1_more_variation', '0_full_range')
ana.combine()
figs = ana.hist_errors_combo(bins=20)
fig = ana.mean_abs_error_combo([7.5])
fig = ana.stdev_error_combo([7.5])
figs = ana.zred_zphot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...

# %%
fig, data = run.photoz.show_fit(727, True, showpz=0.2, show_components=True)
# fig.get_axes()[0].set_ylim([-0.005, 0.020])
fig, data = run.photoz.show_fit(730, True, showpz=0.2, show_components=True)
# Out:
# WARNING: RA column None not found in catalog [eazy.photoz]
# WARNING: DEC column None not found in catalog [eazy.photoz]
# WARNING: RA column None not found in catalog [eazy.photoz]
# WARNING: DEC column None not found in catalog [eazy.photoz]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, data = run.photoz.show_fit(834, True, showpz=0.2, show_components=True)
fig.get_axes()[0].set_ylim([-0.005, 0.020])
fig, data = run.photoz.show_fit(836, True, showpz=0.2, show_components=True)
# Out:
# WARNING: RA column None not found in catalog [eazy.photoz]
# WARNING: DEC column None not found in catalog [eazy.photoz]
# WARNING: RA column None not found in catalog [eazy.photoz]
# WARNING: DEC column None not found in catalog [eazy.photoz]
# /Users/liambrown/repositories/combo_galaxies_part_iii/.venv/lib/python3.12/site-packages/eazy/photoz.py:2734: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, data = run.photoz.show_fit(1260, True, showpz=0.2, show_components=True)
# Out:
# WARNING: RA column None not found in catalog [eazy.photoz]
# WARNING: DEC column None not found in catalog [eazy.photoz]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
run.zout
# Out:
# <Table length=1560>
#   id    z_spec ...                  ABSM_274
#                ...
# int64  float64 ...                 float64[5]
# ------ ------- ... ------------------------------------------
# 100001     2.0 ... -14.513078686844935 .. -14.688116070878138
#  24479     2.0 ... -13.845767968179253 .. -14.068878167153862
#  59326     2.0 ...   -13.608766463889175 .. -13.8388995205298
# 100002     2.0 ... -15.688702381313703 .. -15.883997715176008
#   2921     2.0 ... -13.485071230306403 .. -13.694072771444098
#   2931     2.0 ...                  nan .. -28.36806069943684
#  78317     2.0 ...                 nan .. -25.336294251824313
# 100003     2.0 ...  -17.508535042115803 .. -17.68197406799471
#  90948     2.0 ... -17.140346909065578 .. -17.389444733162257
#    ...     ... ...                                        ...
# 100359    13.9 ... -19.756017823625086 .. -19.991830964494227
#  63761    13.9 ...                 nan .. -31.595374362292375
# ...
